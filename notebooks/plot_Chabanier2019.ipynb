# %% [markdown]
# # Plot P1D measurement from Chabanier et al. (2019)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['savefig.dpi'] = 160
mpl.rcParams['figure.dpi'] = 160
from cup1d.data import p1d_data_PD2013
from cup1d.data import p1d_data_Chabanier2019

# %%
Cha2019=p1d_data_Chabanier2019.P1D_Chabanier2019(add_syst=True)
Cha2019.plot_p1d()

# %% [markdown]
# ### Compare to P1D from Palanque-Delabrouille et al. (2013)

# %%
PD2013=p1d_data_PD2013.P1D_PD2013(add_syst=True)
PD2013.plot_p1d()
