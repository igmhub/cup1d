# %% [markdown]
# # Plot P1D measurement from Chabanier et al. (2019)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['savefig.dpi'] = 160
mpl.rcParams['figure.dpi'] = 160
from cup1d.data import data_PD2013
from cup1d.data import data_Chabanier2019
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8 mpl.rcParams['savefig.dpi'] = 160
#       9 mpl.rcParams['figure.dpi'] = 160
# ---> 10 from cup1d.data import data_PD2013
#      11 from cup1d.data import data_Chabanier2019
#
# File ~/Proyectos/projects/lya/cup1d/cup1d/data/data_PD2013.py:4
#       1 import os
#       2 import numpy as np
# ----> 4 from cup1d.data.base_p1d_data import BaseDataP1D, _drop_zbins
#       7 class P1D_PD2013(BaseDataP1D):
#       8     def __init__(self, zmin=None, zmax=None, use_FFT=True, add_syst=True):
#
# File ~/Proyectos/projects/lya/cup1d/cup1d/data/base_p1d_data.py:7
#       2 import matplotlib.pyplot as plt
#       4 import cup1d
# ----> 7 class BaseDataP1D(object):
#       8     """Base class to store measurements of the 1D power spectrum"""
#      10     BASEDIR = os.path.dirname(cup1d.__path__[0]) + "/data/p1d_measurements/"
#
# File ~/Proyectos/projects/lya/cup1d/cup1d/data/base_p1d_data.py:10, in BaseDataP1D()
#       7 class BaseDataP1D(object):
#       8     """Base class to store measurements of the 1D power spectrum"""
# ---> 10     BASEDIR = os.path.dirname(cup1d.__path__[0]) + "/data/p1d_measurements/"
#      12     def __init__(self, z, k_kms, Pk_kms, cov_Pk_kms):
#      13         """Construct base P1D class, from measured power and covariance"""
#
# NameError: name 'os' is not defined

# %%
Cha2019=data_Chabanier2019.P1D_Chabanier2019(add_syst=True)
Cha2019.plot_p1d()

# %% [markdown]
# ### Compare to P1D from Palanque-Delabrouille et al. (2013)

# %%
PD2013=data_PD2013.P1D_PD2013(add_syst=True)
PD2013.plot_p1d()
