# %% [markdown]
# # Plot P1D measurement from Walther et al. (2018)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['savefig.dpi'] = 120
mpl.rcParams['figure.dpi'] = 120
from cup1d.data import p1d_data_Walther2018

# %% [markdown]
# ### Read P1D from Walther et al. (2018)

# %%
data=p1d_data_Walther2018.P1D_Walther2018()
# Out:
# /Users/font/Programs/igmhub/cup1d//data_files/Walther2018//table5.dat

# %%
data.plot_p1d(xlog=True)
